# %%
from pathlib import Path
import pandas as pd

# %%
pd.options.display.max_columns = 200
pd.options.display.max_rows = 200

# %%
def load_dataset(*, file_name: str, error_bad_lines_bol=True) -> pd.DataFrame:
    dataframe = pd.read_csv(Path(f"{file_name}"), error_bad_lines=error_bad_lines_bol)
    # dataframe["MSSubClass"] = dataframe["MSSubClass"].astype("O")

    # # rename variables beginning with numbers to avoid syntax errors later
    # transformed = dataframe.rename(columns=config.model_config.variables_to_rename)
    return dataframe

# %% [markdown]
# # Orders

# %%
orders_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/orders.csv/part-00000-88935664-b70a-42dc-aa08-e401de62b211-c000.csv")

# %%
orders_df.sort_values(by='created', ascending=False).head()
# Out:
#                         created  billing_address_id  \
# 64598  2021-11-01T00:09:47.787Z             66338.0
# 64223  2021-10-31T23:17:27.783Z             66337.0
# 63640  2021-10-31T22:44:47.146Z             66336.0
# 63300  2021-10-31T22:43:57.425Z             66224.0
# 63175  2021-10-31T22:41:36.210Z             65918.0
#
#                      device_fingerprint        checkout_completed  \
# 64598  5922948613aab556839bc32639f1fe13                       NaN
# 64223  65d3d2b20b710daadd57072607b1aa3b  2021-10-31T23:18:52.324Z
# 63640  fa6fda4dd989d28aa684335a1789cd2f  2021-10-31T22:46:16.231Z
# 63300  63f341ad331fd3e35689a744f3ea77a3  2021-10-31T22:45:31.113Z
# 63175  666bf48fd9b433fef9fcb6187e8adeca  2021-10-31T22:41:53.566Z
#
#        shipping_address_id  total_amount                          merchant_id  \
# 64598              66338.0        2794.0  id_95b185f94abb44f89f51e0b1dfe9c238
# 64223              66337.0        1175.0  id_c8f2c6484fa4444a8598348900692ec8
# ...

# %%
orders_df.sort_values(by='created', ascending=True).head()
# Out:
#                         created  billing_address_id  \
# 47557  2020-04-26T11:22:01.903Z               288.0
# 56944  2020-04-26T11:25:19.979Z               290.0
# 58655  2020-04-26T12:15:52.913Z               296.0
# 59315  2020-04-26T12:24:47.311Z               298.0
# 59764  2020-04-26T18:15:51.772Z               300.0
#
#                      device_fingerprint        checkout_completed  \
# 47557  6535dac51e0987fb23eb632b2e7a0316                       NaN
# 56944  18082b27722abbaec9b4f4a3f8ba48ac                       NaN
# 58655  3761f1820b2c57433617ab317b4d2e07                       NaN
# 59315  6535dac51e0987fb23eb632b2e7a0316  2020-04-26T12:26:30.651Z
# 59764  bd55cb34c4472a85c80e87372684eb2b                       NaN
#
#        shipping_address_id  total_amount                          merchant_id  \
# 47557                287.0         490.0  id_61830ae632e1446eb72a8ea10710bddd
# 56944                289.0         950.0  id_61830ae632e1446eb72a8ea10710bddd
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85372 entries, 0 to 85371
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created              85372 non-null  object
#  1   billing_address_id   66456 non-null  float64
#  2   device_fingerprint   81208 non-null  object
#  3   checkout_completed   56070 non-null  object
#  4   shipping_address_id  78151 non-null  float64
#  5   total_amount         85372 non-null  float64
#  6   merchant_id          85372 non-null  object
#  7   currency             85372 non-null  object
#  8   customer_id          85372 non-null  int64
#  9   checkout_verified    56952 non-null  object
#  10  shipping_amount      78151 non-null  float64
#  11  rules                3636 non-null   object
#  12  reference            85372 non-null  object
#  13  merchant_name        85372 non-null  object
#  14  payment_interval     5626 non-null   float64
# ...

# %%
orders_h2_df = orders_df[orders_df['created'] > '2021-06-30']

# %%
orders_h2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48072 entries, 0 to 85362
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created              48072 non-null  object
#  1   billing_address_id   40648 non-null  float64
#  2   device_fingerprint   47209 non-null  object
#  3   checkout_completed   31158 non-null  object
#  4   shipping_address_id  45836 non-null  float64
#  5   total_amount         48072 non-null  float64
#  6   merchant_id          48072 non-null  object
#  7   currency             48072 non-null  object
#  8   customer_id          48072 non-null  int64
#  9   checkout_verified    34784 non-null  object
#  10  shipping_amount      45836 non-null  float64
#  11  rules                2401 non-null   object
#  12  reference            48072 non-null  object
#  13  merchant_name        48072 non-null  object
#  14  payment_interval     1336 non-null   float64
# ...

# %%
orders_h2_df.describe()
# Out:
#        billing_address_id  shipping_address_id   total_amount   customer_id  \
# count        40648.000000         45836.000000   48072.000000  48072.000000
# mean         47513.951215         47176.893446    1552.093779  37254.494071
# std          11264.039570         11708.959554    2920.422614  10441.310458
# min            682.000000           514.000000       0.000000    349.000000
# 25%          38783.000000         38376.000000     199.500000  29594.750000
# 50%          48172.000000         47848.000000     414.750000  37680.000000
# 75%          56610.000000         56654.500000    1470.000000  45622.250000
# max          66338.000000         66338.000000  200000.000000  54679.000000
#
#        shipping_amount  payment_interval      order_id  num_instalments
# count     45836.000000       1336.000000  48072.000000     48072.000000
# mean          6.019950          7.759731  67782.023860         3.053898
# ...

# %%
orders_h2_df[orders_h2_df['total_amount'] == 200000.000000]
# Out:
#                         created  billing_address_id  \
# 12528  2021-08-27T03:20:29.693Z             41300.0
#
#                      device_fingerprint checkout_completed  \
# 12528  51195c083339dbc45441c32002313929                NaN
#
#        shipping_address_id  total_amount                          merchant_id  \
# 12528              41299.0      200000.0  id_96f5db7bfe904d858520e7dfb07a4b71
#
#       currency  customer_id checkout_verified  shipping_amount rules  \
# 12528      AED        32487               NaN              0.0   NaN
#
#                  reference      merchant_name  payment_interval  \
# 12528  11618-612859fd5fe67  The luxury flavor               NaN
#
#                  status_changed  order_id checkout_type date_joined   status  \
# 12528  2021-08-27T03:20:29.677Z     56350       default         NaN  pending
#
#                       email  num_instalments user_agent ip_address
# 12528  Asalahbabi@gmail.com                1        NaN        NaN

# %%
for c in orders_h2_df.columns:
    print(orders_h2_df[c].value_counts())
# Out:
# 2021-09-01T17:05:52.378Z    2
# 2021-10-29T05:14:42.690Z    2
# 2021-07-05T14:02:01.774Z    2
# 2021-08-16T13:28:52.148Z    2
# 2021-10-29T20:22:53.216Z    1
#                            ..
# 2021-10-30T22:07:37.130Z    1
# 2021-08-13T19:45:59.584Z    1
# 2021-08-23T13:46:58.829Z    1
# 2021-08-13T14:40:57.445Z    1
# 2021-10-02T19:40:57.178Z    1
# Name: created, Length: 48068, dtype: int64
# 33246.0    49
# 23853.0    40
# 40644.0    34
# 56517.0    33
# 48229.0    29
#            ..
# 58516.0     1
# 51665.0     1
# 59551.0     1
# 42199.0     1
# 48001.0     1
# Name: billing_address_id, Length: 26930, dtype: int64
# 425db8d63ca25389de6338f964b168b8    633
# 14b674c5d7893b17901f92880960d9ec    620
# 9151e58b5536837f618fd6972dd77fda    479
# 7c782ff6d907f5f0aeeb17bf3ada8326    416
# 7493fd707633eec81265ccbb7298122d    380
#                                    ...
# 6e28a92e1012475abaf2c9f9c51e1abe      1
# cb3d95c85419565a1303fc92bae427b7      1
# ...

# %% [markdown]
# # Customers

# %%
customers_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/customers.csv/part-00000-c5e6d7f4-2e16-449d-8195-538e62f54143-c000.csv")

# %%
customers_df.shape
# Out:
# (35372, 7)

# %%
customers_df.head()
# Out:
#    customer_id        id_number         phone date_of_birth blacklisted  \
# 0        20863              NaN  971523107593           NaN         NaN
# 1        30986  784198604919518  971557778727           NaN         NaN
# 2        22809              NaN  966567180228           NaN         NaN
# 3        11650              NaN  971561333473           NaN         NaN
# 4        18296       1044917555  966500566646           NaN         NaN
#
#   disabled                   created
# 0      NaN  2021-09-06T05:33:02.615Z
# 1      NaN  2021-10-16T14:15:53.452Z
# 2      NaN  2021-09-17T17:49:24.713Z
# 3      NaN  2021-05-29T19:48:13.210Z
# 4      NaN  2021-08-18T23:35:28.527Z

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35372 entries, 0 to 35371
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    35372 non-null  int64
#  1   id_number      30249 non-null  object
#  2   phone          35372 non-null  int64
#  3   date_of_birth  22574 non-null  object
#  4   blacklisted    2 non-null      object
#  5   disabled       401 non-null    object
#  6   created        35372 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 1.9+ MB

# %%
customers_df['blacklisted'].value_counts()
# Out:
# 2021-04-08T05:23:50.000Z    1
# 2021-04-08T05:24:09.000Z    1
# Name: blacklisted, dtype: int64

# %%
for c in customers_df.columns:
    print(customers_df[c].value_counts())
# Out:
# 20863    1
# 29770    1
# 29582    1
# 16244    1
# 27943    1
#         ..
# 26157    1
# 12131    1
# 34908    1
# 24452    1
# 27893    1
# Name: customer_id, Length: 35372, dtype: int64
# 784199182613150    47
# 000000000000000    13
# 784198741519031    11
# 784198957058534     5
# 784199743509277     4
#                    ..
# 784199347268270     1
# 784199052104371     1
# 1009412543          1
# 784198157980859     1
# 784197829215173     1
# Name: id_number, Length: 29628, dtype: int64
# 971564772462    3
# 971566784909    3
# 971553486112    3
# 971566408965    2
# 971547623365    2
#                ..
# 971501496974    1
# 971557694453    1
# 971508189132    1
# 971506197782    1
# 971503783043    1
# Name: phone, Length: 34978, dtype: int64
# 1991-11-05    48
# 1987-01-01    27
# 1982-01-01    16
# 1988-01-01    15
# 1986-01-01    15
#               ..
# 1965-09-18     1
# 1992-08-04     1
# 1980-05-22     1
# 2003-07-04     1
# 1978-09-01     1
# ...

# %% [markdown]
# # Addresses

# %%
addresses_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/addresses.csv/part-00000-0bb954d5-9b9f-4692-9f4b-b5432ce62fc5-c000.csv", error_bad_lines_bol=False)
# Out:
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/1930173166.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   addresses_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/addresses.csv/part-00000-0bb954d5-9b9f-4692-9f4b-b5432ce62fc5-c000.csv", error_bad_lines_bol=False)
# ...

# %%
addresses_df.head(100)
# Out:
#        id     first_name                             last_name  \
# 0   29462           John                       Patrick Glaraga
# 1   50070        Abigail                               Ednalig
# 2   57364           Ohud                                  Omar
# 3   54477          بدريه                              محمد علي
# 4   41598           Maha                              Al Ketbi
# 5   61789    Prinzcheska                                Harabe
# 6   53216          Sonal                                    A.
# 7   37231          Samah                                 Elsir
# 8    5951        Maitham                                Husain
# 9   17839           Juan                        vincent carino
# 10  62611         Nyasha                                Chaipa
# 11  14884      RaniMaria                                 Deepu
# 12  12143         Nikola                              Amanovic
# 13  14720  Mohammed Amir                            Telegraphy
# ...

# %%
addresses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65986 entries, 0 to 65985
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           65986 non-null  object
#  1   first_name   65970 non-null  object
#  2   last_name    65903 non-null  object
#  3   line1        57177 non-null  object
#  4   line2        19861 non-null  object
#  5   city         65977 non-null  object
#  6   state        23241 non-null  object
#  7   postal_code  12891 non-null  object
#  8   phone        48588 non-null  object
#  9   alt_phone    579 non-null    object
#  10  country_id   65981 non-null  object
#  11  uid          65978 non-null  object
# dtypes: object(12)
# memory usage: 6.0+ MB

# %% [markdown]
# # Instalment-Plans

# %%
instalment_plans_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/instalment-plans.csv/part-00000-ae9ff2b4-082c-4818-a11f-23987f8e22f3-c000.csv")
# Out:
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/1854447357.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   instalment_plans_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/instalment-plans.csv/part-00000-ae9ff2b4-082c-4818-a11f-23987f8e22f3-c000.csv")
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/1854447357.py:1: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   instalment_plans_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/instalment-plans.csv/part-00000-ae9ff2b4-082c-4818-a11f-23987f8e22f3-c000.csv")

# %%
instalment_plans_df.shape
# Out:
# (41818, 40)

# %%
instalment_plans_df.head()
# Out:
#                     created        payment_method_fingerprint  \
# 0  2021-10-25T16:54:11.336Z  8df936d8a8c343688023df433b5a97cf
# 1  2021-10-07T06:40:48.026Z  de4f37a4b75949baa41a021f67911b15
# 2  2021-10-06T08:52:41.611Z  de4f37a4b75949baa41a021f67911b15
# 3  2021-06-15T12:35:30.476Z  4066a0abf23040f8a5c24ff29ee08c53
# 4  2021-07-12T15:55:05.420Z  4066a0abf23040f8a5c24ff29ee08c53
#
#    downpayment_amount  billing_address_id                device_fingerprint  \
# 0               80.00             62807.0  38baad52798b0cf9c88e794215a6f472
# 1               64.00             55137.0  62bb9f5093a1336178024efd86040232
# 2               36.00             55137.0  f9b83903fb9a798fc1f69e3fc5250155
# 3              331.67             28155.0  e9264dcbef5c62b64a2c925def27bddb
# 4              308.33             28155.0  e9264dcbef5c62b64a2c925def27bddb
#
#    total_downpayment        checkout_completed payment_method_brand    plan  \
# ...

# %%
instalment_plans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41818 entries, 0 to 41817
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   created                      41818 non-null  object
#  1   payment_method_fingerprint   41818 non-null  object
#  2   downpayment_amount           41818 non-null  float64
#  3   billing_address_id           32952 non-null  float64
#  4   device_fingerprint           41312 non-null  object
#  5   total_downpayment            41818 non-null  float64
#  6   checkout_completed           41818 non-null  object
#  7   payment_method_brand         41817 non-null  object
#  8   plan                         41818 non-null  object
#  9   payment_method_expires       41818 non-null  object
#  10  shipping_address_id          38350 non-null  float64
#  11  total_amount                 41818 non-null  float64
# ...

# %%
instalment_plans_df.describe()
# Out:
#        downpayment_amount  billing_address_id  total_downpayment  \
# count        41818.000000        32952.000000       41818.000000
# mean           559.760136        34588.118991         538.420534
# std           1729.927477        18580.342143        1689.671257
# min              0.050000          298.000000           0.000000
# 25%             77.330000        19501.000000          70.000000
# 50%            146.670000        34782.500000         138.250000
# 75%            418.247500        50732.250000         390.000000
# max          86000.000000        66336.000000       86000.000000
#
#        shipping_address_id  total_amount   customer_id     id_number  \
# count         38350.000000  41818.000000  34018.000000  3.401500e+04
# mean          33461.108787   1283.270736  15165.825828  7.509264e+14
# std           18700.544635   2520.625680   9900.210516  1.579166e+14
# min             297.000000      0.050000     68.000000  0.000000e+00
# ...

# %%
for c in instalment_plans_df.columns:
    print(instalment_plans_df[c].value_counts())
# Out:
# 2021-10-25T16:54:11.336Z    1
# 2021-09-18T11:04:15.620Z    1
# 2021-07-09T13:35:06.484Z    1
# 2021-03-07T09:16:56.591Z    1
# 2021-04-05T10:11:54.225Z    1
#                            ..
# 2020-10-20T16:01:34.977Z    1
# 2020-11-17T15:10:02.779Z    1
# 2021-09-28T12:50:01.264Z    1
# 2021-01-20T07:52:40.761Z    1
# 2021-06-15T12:24:51.153Z    1
# Name: created, Length: 41818, dtype: int64
# 50188a134b6f41b08513f5801f3b19d4    28
# 7f2c5d7142c94b66ab05c12f766ca2cf    26
# fe64de92065c449eb8aa61ba132161ce    24
# d56a9e6106bd4db28b81ee354712874a    22
# 29b5651f86d8408da2351ee86b075db4    22
#                                     ..
# 278b445843ae407fba3a225af34c4237     1
# 48fdb9a42c5646cebcd54a16c2c8a217     1
# fce8dbdc68354a88be835fcb00820c95     1
# 90bde86e8de34adb8da68a80da1a4bcd     1
# dd1887a649ea4fe182119ade8cd3ede2     1
# Name: payment_method_fingerprint, Length: 30882, dtype: int64
# 138.25    992
# 85.75     988
# 68.25     853
# 79.00     685
# 208.25    572
# ...

# %% [markdown]
# # Instalments

# %%
instalments_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/instalments.csv/part-00000-57a570eb-933b-411f-90b1-67e12baf59af-c000.csv")
# Out:
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/1898104514.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   instalments_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/instalments.csv/part-00000-57a570eb-933b-411f-90b1-67e12baf59af-c000.csv")

# %%
instalments_df.shape
# Out:
# (85736, 9)

# %%
instalments_df.head(20)
# Out:
#     order  refunded_amount  penalty_fee   amount  instalment_plan_id  \
# 0       0             0.00         25.0   138.25                6237
# 1       1             0.00          0.0   138.25                6237
# 2       1             0.00          0.0    82.67               21494
# 3       0             0.00          0.0    82.67               21494
# 4       0             0.00          0.0    39.33               33077
# 5       1             0.00          0.0    39.33               33077
# 6       0             0.00          0.0   138.25                8965
# 7       1             0.00          0.0   138.25                8965
# 8       0             0.00          0.0   284.33               16805
# 9       1           230.00          0.0   284.33               16805
# 10      0             0.00          0.0    99.67               42482
# 11      1             0.00          0.0    99.67               42482
# 12      1             0.00          0.0   118.00               41753
# ...

# %%
instalments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85736 entries, 0 to 85735
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order               85736 non-null  int64
#  1   refunded_amount     85736 non-null  float64
#  2   penalty_fee         85736 non-null  float64
#  3   amount              85736 non-null  float64
#  4   instalment_plan_id  85736 non-null  int64
#  5   scheduled           85736 non-null  object
#  6   completed           54702 non-null  object
#  7   status              85736 non-null  object
#  8   total               85736 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 5.9+ MB

# %%
for c in instalments_df.columns:
    print(instalments_df[c].value_counts())
# Out:
# 0     33929
# 1     32845
# 2      5420
# 3      2205
# 4      2204
# 5      2203
# 6      2200
# 7      1186
# 8      1186
# 10     1175
# 9      1175
# 18        1
# 13        1
# 14        1
# 15        1
# 12        1
# 11        1
# 16        1
# 17        1
# Name: order, dtype: int64
# 0.00      80674
# 79.00       284
# 49.00       199
# 138.25      124
# 85.75       107
#           ...
# 183.33        1
# 241.67        1
# 320.00        1
# 97.50         1
# 598.50        1
# Name: refunded_amount, Length: 1502, dtype: int64
# 0.00     81611
# 25.00     2386
# 55.00     1211
# 26.25      100
# 30.00       34
# 57.75       27
# 51.19       20
# 9.31        18
# 22.71       13
# 48.69       10
# 28.75        7
# 18.75        7
# 35.94        6
# 50.00        5
# 37.50        5
# 21.25        5
# 22.25        5
# 22.50        5
# 43.75        5
# 40.00        5
# 12.00        4
# 51.25        4
# 7.50         4
# 24.25        4
# 39.31        4
# 41.25        4
# ...

# %%
instalments_df[instalments_df['status'] == 'unpaid']
# Out:
#        order  refunded_amount  penalty_fee   amount  instalment_plan_id  \
# 41         0              0.0         0.00  3707.50               37136
# 145        1              0.0        16.25    95.00               25058
# 146        0              0.0        55.00    95.00               25058
# 178        0              0.0        18.50    24.67               36083
# 300        1              0.0        55.00   755.47               11404
# ...      ...              ...          ...      ...                 ...
# 85552      0              0.0        55.00   283.33               31500
# 85582      0              0.0        55.00   263.00               15418
# 85583      1            122.0        55.00   263.00               15418
# 85654      1              0.0        55.00   166.67               17489
# 85655      0              0.0        55.00   166.67               17489
#
#         scheduled completed  status    total
# 41     2021-10-31       NaN  unpaid  3707.50
# ...

# %%
instalments_df[instalments_df['instalment_plan_id'] == 6237]
# Out:
#    order  refunded_amount  penalty_fee  amount  instalment_plan_id  \
# 0      0              0.0         25.0  138.25                6237
# 1      1              0.0          0.0  138.25                6237
#
#     scheduled                 completed status   total
# 0  2021-02-28  2021-02-28T15:15:53.716Z   paid  163.25
# 1  2021-03-31  2021-02-28T15:15:53.716Z   paid  138.25

# %%
instalment_plans_df[instalment_plans_df['instalment_plan_id'] == 6237]
# Out:
#                        created        payment_method_fingerprint  \
# 7377  2021-01-31T20:05:07.077Z  6f8ccc45ddd84045b6d18ef5f0544820
#
#       downpayment_amount  billing_address_id  \
# 7377              138.25                 NaN
#
#                     device_fingerprint  total_downpayment  \
# 7377  0b3f6b6efcab68c03df3bbb4c92d9953             138.25
#
#             checkout_completed payment_method_brand    plan  \
# 7377  2021-01-31T20:03:54.307Z                 visa  funded
#
#      payment_method_expires  shipping_address_id  total_amount  \
# 7377             2026-02-28               8298.0        414.75
#
#                               merchant_id currency  customer_id gateway_name  \
# 7377  id_20ee69719df849dea7fb965529499340      AED       3837.0     checkout
#
#          id_number         checkout_verified cancelled payment_method_country  \
# 7377  7.841987e+14  2021-01-31T20:00:47.765Z       NaN                     AE
#
# ...

# %%
instalment_plans_df[instalment_plans_df['order_id'] == 11916]
# Out:
#                        created        payment_method_fingerprint  \
# 7377  2021-01-31T20:05:07.077Z  6f8ccc45ddd84045b6d18ef5f0544820
#
#       downpayment_amount  billing_address_id  \
# 7377              138.25                 NaN
#
#                     device_fingerprint  total_downpayment  \
# 7377  0b3f6b6efcab68c03df3bbb4c92d9953             138.25
#
#             checkout_completed payment_method_brand    plan  \
# 7377  2021-01-31T20:03:54.307Z                 visa  funded
#
#      payment_method_expires  shipping_address_id  total_amount  \
# 7377             2026-02-28               8298.0        414.75
#
#                               merchant_id currency  customer_id gateway_name  \
# 7377  id_20ee69719df849dea7fb965529499340      AED       3837.0     checkout
#
#          id_number         checkout_verified cancelled payment_method_country  \
# 7377  7.841987e+14  2021-01-31T20:00:47.765Z       NaN                     AE
#
# ...

# %%
orders_df[orders_df['order_id'] == 11916]
# Out:
#                         created  billing_address_id  \
# 16711  2021-01-31T19:55:20.222Z                 NaN
#
#                      device_fingerprint        checkout_completed  \
# 16711  0b3f6b6efcab68c03df3bbb4c92d9953  2021-01-31T20:03:54.307Z
#
#        shipping_address_id  total_amount                          merchant_id  \
# 16711               8298.0        414.75  id_20ee69719df849dea7fb965529499340
#
#       currency  customer_id         checkout_verified  shipping_amount rules  \
# 16711      AED         7584  2021-01-31T20:00:47.765Z              0.0   NaN
#
#            reference    merchant_name  payment_interval  \
# 16711  PPC-000001932  The Entertainer               NaN
#
#                  status_changed  order_id checkout_type date_joined    status  \
# 16711  2021-01-31T20:05:15.712Z     11916       default         NaN  captured
#
#                                email  num_instalments  \
# 16711  mohamed.hamed1987@hotmail.com                3
#
# ...

# %%
customers_df[customers_df['customer_id'] == 3837.0]
# Out:
#       customer_id        id_number         phone date_of_birth blacklisted  \
# 1749         3837  784198718270212  971553360246    1987-11-07         NaN
#
#      disabled                   created
# 1749      NaN  2021-01-31T20:00:47.758Z

# %%
customers_df[customers_df['customer_id'] == 7584]
# Out:
#        customer_id        id_number         phone date_of_birth blacklisted  \
# 12384         7584  784199169602853  971528023926    1991-10-28         NaN
#
#       disabled                   created
# 12384      NaN  2021-04-14T06:14:01.653Z

# %% [markdown]
# # Transactions

# %%
transactions_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/transactions.csv/part-00000-d894197e-e5fa-452b-bcaa-2b277ab287ce-c000.csv")
# Out:
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/3864120460.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   transactions_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/transactions.csv/part-00000-d894197e-e5fa-452b-bcaa-2b277ab287ce-c000.csv")

# %%
transactions_df.shape
# Out:
# (56509, 15)

# %%
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56509 entries, 0 to 56508
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   created          56509 non-null  object
#  1   fee_tax_rate     56509 non-null  float64
#  2   payment_id       50403 non-null  float64
#  3   plan             56509 non-null  object
#  4   type             56509 non-null  object
#  5   fee_rate         56509 non-null  float64
#  6   total            56509 non-null  float64
#  7   merchant_id      56509 non-null  int64
#  8   amount           56509 non-null  float64
#  9   currency         56509 non-null  object
#  10  scheduled        56509 non-null  object
#  11  order_id         56509 non-null  int64
#  12  num_instalments  56509 non-null  int64
#  13  fee_amount       56509 non-null  float64
#  14  id               56509 non-null  int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 6.5+ MB

# %%
transactions_df.head()
# Out:
#                     created  fee_tax_rate  payment_id    plan   type  \
# 0  2021-10-29T20:24:18.541Z           0.0      4732.0  funded  order
# 1  2021-06-14T03:16:31.203Z           0.0      2289.0  funded  order
# 2  2021-07-08T05:43:59.596Z           0.0      2665.0  funded  order
# 3  2021-05-03T14:40:10.571Z           0.0      1807.0  funded  order
# 4  2021-07-03T12:39:43.588Z           0.0      2533.0  funded  order
#
#    fee_rate   total  merchant_id  amount currency                 scheduled  \
# 0      3.29   13.12          271   398.7      AED  2021-10-29T20:24:18.541Z
# 1      2.70    3.97          245   110.0      AED  2021-06-14T03:16:31.203Z
# 2      4.00   25.12          103   603.0      AED  2021-07-08T05:43:59.596Z
# 3      4.99  304.14          142  6075.0      AED  2021-05-03T14:40:10.571Z
# 4      3.29    8.52          214   259.0      AED  2021-07-03T12:39:43.588Z
#
#    order_id  num_instalments  fee_amount     id
# ...

# %%
transactions_df.describe()
# Out:
#        fee_tax_rate    payment_id      fee_rate         total   merchant_id  \
# count  56509.000000  50403.000000  56509.000000  56509.000000  56509.000000
# mean       0.005840   2700.926969      3.078357     32.102048    183.118105
# std        0.295912   1309.152199      0.816067     76.539808     67.479215
# min        0.000000     70.000000      0.000000   -514.500000    101.000000
# 25%        0.000000   1652.000000      2.790000      3.360000    120.000000
# 50%        0.000000   2687.000000      3.290000      8.640000    161.000000
# 75%        0.000000   3931.000000      3.290000     20.620000    230.000000
# max       15.000000   4750.000000      9.990000   2498.500000    470.000000
#
#              amount      order_id  num_instalments    fee_amount            id
# count  56509.000000  56509.000000     56509.000000  56509.000000  56509.000000
# mean     902.176451  44054.079244         4.808827      0.607089  30708.058132
# ...

# %%
transactions_df[transactions_df['order_id'] == 11916]
# Out:
#                         created  fee_tax_rate  payment_id    plan   type  \
# 10906  2021-01-31T20:05:15.784Z           0.0      1048.0  funded  order
#
#        fee_rate  total  merchant_id  amount currency  \
# 10906      2.79  11.57          161  414.75      AED
#
#                       scheduled  order_id  num_instalments  fee_amount    id
# 10906  2021-01-31T20:05:15.784Z     11916                3         0.0  9939

# %% [markdown]
# # Refunds

# %%
refunds_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/refunds.csv/part-00000-477dfc63-2ae1-44a7-bd9c-dd5124f5eba8-c000.csv")
# Out:
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/399793929.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   refunds_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/refunds.csv/part-00000-477dfc63-2ae1-44a7-bd9c-dd5124f5eba8-c000.csv")

# %%
refunds_df.shape
# Out:
# (2858, 5)

# %%
refunds_df.head()
# Out:
#                     created   amount  order_id   full    id
# 0  2021-04-18T15:12:55.283Z   257.25     22998   True  1042
# 1  2021-01-04T11:56:46.099Z  1508.76      5797   True   271
# 2  2021-03-25T16:39:17.961Z  2600.00     19929   True   863
# 3  2021-04-21T17:20:10.120Z   100.00     25102  False  1091
# 4  2021-10-20T06:57:09.722Z   450.00     84576   True  3373

# %%
refunds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2858 entries, 0 to 2857
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   created   2858 non-null   object
#  1   amount    2858 non-null   float64
#  2   order_id  2858 non-null   int64
#  3   full      2858 non-null   bool
#  4   id        2858 non-null   int64
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 92.2+ KB

# %% [markdown]
# # Cart

# %%
cart_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/cart.csv/part-00000-b40a8bc8-d3a0-4ef2-8c9f-09c279ac26db-c000.csv")
# Out:
# /var/folders/5b/q1b1f10s6p39_ns07cll2dxh0000gn/T/ipykernel_2510/2375214884.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   cart_df = load_dataset(file_name="/Users/ronsnir/Documents/postpay/data/mydataset/cart.csv/part-00000-b40a8bc8-d3a0-4ef2-8c9f-09c279ac26db-c000.csv")

# %%
cart_df.shape
# Out:
# (276114, 10)

# %%
cart_df.head()
# Out:
#   image_url  unit_price  item_id  merchant_id  url description  \
# 0       NaN        12.0   117295          271  NaN         NaN
# 1       NaN        19.0   157390          271  NaN         NaN
# 2       NaN       349.0    28995          214  NaN         NaN
# 3       NaN        39.0    63400          271  NaN         NaN
# 4       NaN        19.0   147634          271  NaN         NaN
#
#                                               name  reference  qty  order_id
# 0         Warm Vanilla Sugar Creamy Luxe Hand Soap  253247308    1     84388
# 1               Into the Night Fine Fragrance Mist  260130185    2     97927
# 2             Nike Air Max 270 React - Men's Shoes   21076589    1     42085
# 3  Champagne Toast Travel Size Fine Fragrance Mist  238968563    3     59783
# 4                    Dark Kiss Fine Fragrance Mist  258689534   60     95785

# %%
cart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276114 entries, 0 to 276113
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   image_url    70482 non-null   object
#  1   unit_price   276114 non-null  float64
#  2   item_id      276114 non-null  int64
#  3   merchant_id  276114 non-null  int64
#  4   url          94213 non-null   object
#  5   description  31722 non-null   object
#  6   name         276114 non-null  object
#  7   reference    276114 non-null  object
#  8   qty          276114 non-null  int64
#  9   order_id     276114 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 21.1+ MB

# %%
cart_df[cart_df['url'].notnull()].head()
# Out:
#                                             image_url  unit_price  item_id  \
# 7   https://cdn.shopify.com/s/files/1/0506/9032/67...         5.0    16448
# 8   https://cdn.shopify.com/s/files/1/0506/9032/67...         5.0    16448
# 9   https://cdn.shopify.com/s/files/1/0506/9032/67...        10.0    16448
# 10  https://cdn.shopify.com/s/files/1/0506/9032/67...         7.0    16448
# 11  https://cdn.shopify.com/s/files/1/0506/9032/67...         5.0    16448
#
#     merchant_id                                                url  \
# 7           256  https://ecogardenz.myshopify.com/products/arvi...
# 8           256  https://ecogardenz.myshopify.com/products/arvi...
# 9           256  https://ecogardenz.myshopify.com/products/arvi...
# 10          256  https://ecogardenz.myshopify.com/products/arvi...
# 11          256  https://ecogardenz.myshopify.com/products/arvi...
#
#                                           description        name  \
# ...

# %%
cart_df['name'].value_counts()
# Out:
# Dubai Classic 2021                              5510
# UAE Bundle 2021                                 3494
# Refundable Chiller Bag Deposit (non taxable)    2268
# Taste x 30 (2 weeks FREE)                       1790
# Abu Dhabi Classic 2021                          1421
#                                                 ...
# Ava Regency Jewelry Box Collection                 1
# Coach Dreams Eau De Parfum 90ML                    1
# Document Case in Intrecciato Calfskin              1
# Dermacol Make-up Cover - Cover No. 224             1
# Stems of Pampas                                    1
# Name: name, Length: 37134, dtype: int64

# %%
cart_df[cart_df['name'] == 'Dubai Classic 2021']['url'].iloc[5]
# Out:
# 'https://www.theentertainerme.com/Dubai-N-Emirates/products/mobile/dubai-2021'

# %% [markdown]
# # Tests

# %%
instalments_df[instalments_df['instalment_plan_id'] == 6237]
# Out:
#    order  refunded_amount  penalty_fee  amount  instalment_plan_id  \
# 0      0              0.0         25.0  138.25                6237
# 1      1              0.0          0.0  138.25                6237
#
#     scheduled                 completed status   total
# 0  2021-02-28  2021-02-28T15:15:53.716Z   paid  163.25
# 1  2021-03-31  2021-02-28T15:15:53.716Z   paid  138.25

# %%
instalment_plans_df[instalment_plans_df['instalment_plan_id'] == 6237]
# Out:
#                        created        payment_method_fingerprint  \
# 7377  2021-01-31T20:05:07.077Z  6f8ccc45ddd84045b6d18ef5f0544820
#
#       downpayment_amount  billing_address_id  \
# 7377              138.25                 NaN
#
#                     device_fingerprint  total_downpayment  \
# 7377  0b3f6b6efcab68c03df3bbb4c92d9953             138.25
#
#             checkout_completed payment_method_brand    plan  \
# 7377  2021-01-31T20:03:54.307Z                 visa  funded
#
#      payment_method_expires  shipping_address_id  total_amount  \
# 7377             2026-02-28               8298.0        414.75
#
#                               merchant_id currency  customer_id gateway_name  \
# 7377  id_20ee69719df849dea7fb965529499340      AED       3837.0     checkout
#
#          id_number         checkout_verified cancelled payment_method_country  \
# 7377  7.841987e+14  2021-01-31T20:00:47.765Z       NaN                     AE
#
# ...

# %%
instalment_plans_df[instalment_plans_df['order_id'] == 11916]
# Out:
#                        created        payment_method_fingerprint  \
# 7377  2021-01-31T20:05:07.077Z  6f8ccc45ddd84045b6d18ef5f0544820
#
#       downpayment_amount  billing_address_id  \
# 7377              138.25                 NaN
#
#                     device_fingerprint  total_downpayment  \
# 7377  0b3f6b6efcab68c03df3bbb4c92d9953             138.25
#
#             checkout_completed payment_method_brand    plan  \
# 7377  2021-01-31T20:03:54.307Z                 visa  funded
#
#      payment_method_expires  shipping_address_id  total_amount  \
# 7377             2026-02-28               8298.0        414.75
#
#                               merchant_id currency  customer_id gateway_name  \
# 7377  id_20ee69719df849dea7fb965529499340      AED       3837.0     checkout
#
#          id_number         checkout_verified cancelled payment_method_country  \
# 7377  7.841987e+14  2021-01-31T20:00:47.765Z       NaN                     AE
#
# ...

# %%
orders_df[orders_df['order_id'] == 11916]
# Out:
#                         created  billing_address_id  \
# 16711  2021-01-31T19:55:20.222Z                 NaN
#
#                      device_fingerprint        checkout_completed  \
# 16711  0b3f6b6efcab68c03df3bbb4c92d9953  2021-01-31T20:03:54.307Z
#
#        shipping_address_id  total_amount                          merchant_id  \
# 16711               8298.0        414.75  id_20ee69719df849dea7fb965529499340
#
#       currency  customer_id         checkout_verified  shipping_amount rules  \
# 16711      AED         7584  2021-01-31T20:00:47.765Z              0.0   NaN
#
#            reference    merchant_name  payment_interval  \
# 16711  PPC-000001932  The Entertainer               NaN
#
#                  status_changed  order_id checkout_type date_joined    status  \
# 16711  2021-01-31T20:05:15.712Z     11916       default         NaN  captured
#
#                                email  num_instalments  \
# 16711  mohamed.hamed1987@hotmail.com                3
#
# ...

# %%
customers_df[customers_df['customer_id'] == 3837.0] # From instalment_plans_df
# Out:
#       customer_id        id_number         phone date_of_birth blacklisted  \
# 1749         3837  784198718270212  971553360246    1987-11-07         NaN
#
#      disabled                   created
# 1749      NaN  2021-01-31T20:00:47.758Z

# %%
customers_df[customers_df['customer_id'] == 7584] # From orders_df
# Out:
#        customer_id        id_number         phone date_of_birth blacklisted  \
# 12384         7584  784199169602853  971528023926    1991-10-28         NaN
#
#       disabled                   created
# 12384      NaN  2021-04-14T06:14:01.653Z

# %%
transactions_df[transactions_df['order_id'] == 11916]
# Out:
#                         created  fee_tax_rate  payment_id    plan   type  \
# 10906  2021-01-31T20:05:15.784Z           0.0      1048.0  funded  order
#
#        fee_rate  total  merchant_id  amount currency  \
# 10906      2.79  11.57          161  414.75      AED
#
#                       scheduled  order_id  num_instalments  fee_amount    id
# 10906  2021-01-31T20:05:15.784Z     11916                3         0.0  9939

# %% [markdown]
# # Tests 2 - Immature order

# %%
instalment_plans_df[instalment_plans_df['order_id'] == 93401]
# Out:
#                         created        payment_method_fingerprint  \
# 37920  2021-10-31T22:43:41.547Z  825593b12c484c85928e7dff13521950
#
#        downpayment_amount  billing_address_id  \
# 37920             1081.67             65918.0
#
#                      device_fingerprint  total_downpayment  \
# 37920  666bf48fd9b433fef9fcb6187e8adeca            1081.67
#
#              checkout_completed payment_method_brand    plan  \
# 37920  2021-10-31T22:41:53.566Z                 visa  funded
#
#       payment_method_expires  shipping_address_id  total_amount  \
# 37920             2024-07-31              65918.0        3245.0
#
#                                merchant_id currency  customer_id gateway_name  \
# 37920  id_c8f2c6484fa4444a8598348900692ec8      SAR      35416.0   checkoutV3
#
#           id_number         checkout_verified cancelled  \
# 37920  1.062731e+09  2021-10-31T22:41:53.600Z       NaN
#
#       payment_method_country  shipping_amount                 reference  \
# ...

# %%
instalments_df[instalments_df['instalment_plan_id'] == 48160]
# Out:
#        order  refunded_amount  penalty_fee   amount  instalment_plan_id  \
# 85336      1              0.0          0.0  1081.67               48160
# 85337      0              0.0          0.0  1081.67               48160
#
#         scheduled completed status    total
# 85336  2021-12-31       NaN    due  1081.67
# 85337  2021-11-30       NaN    due  1081.67

# %%
orders_df[orders_df['order_id'] == 93401]
# Out:
#                         created  billing_address_id  \
# 63175  2021-10-31T22:41:36.210Z             65918.0
#
#                      device_fingerprint        checkout_completed  \
# 63175  666bf48fd9b433fef9fcb6187e8adeca  2021-10-31T22:41:53.566Z
#
#        shipping_address_id  total_amount                          merchant_id  \
# 63175              65918.0        3245.0  id_c8f2c6484fa4444a8598348900692ec8
#
#       currency  customer_id         checkout_verified  shipping_amount rules  \
# 63175      SAR        54676  2021-10-31T22:41:53.600Z              0.0   NaN
#
#                       reference merchant_name  payment_interval  \
# 63175  863813436724260296234175        Ounass               NaN
#
#                  status_changed  order_id checkout_type date_joined    status  \
# 63175  2021-10-31T22:43:48.884Z     93401       default         NaN  captured
#
#                                      email  num_instalments  \
# ...

# %%
customers_df[customers_df['customer_id'] == 35416.0] # From instalment_plans_df
# Out:
#        customer_id   id_number         phone date_of_birth blacklisted  \
# 18462        35416  1062731326  966541114229           NaN         NaN
#
#       disabled                   created
# 18462      NaN  2021-10-30T20:21:05.409Z

# %%
transactions_df[transactions_df['order_id'] == 93401]
# Out:
#                         created  fee_tax_rate  payment_id    plan   type  \
# 41829  2021-10-31T22:43:48.960Z           0.0         NaN  funded  order
#
#        fee_rate  total  merchant_id  amount currency  \
# 41829      2.45   79.5          209  3245.0      SAR
#
#                       scheduled  order_id  num_instalments  fee_amount     id
# 41829  2021-10-31T22:43:48.960Z     93401                3         0.0  60771

# %% [markdown]
# # Tests 3 - Unpaid

# %%
instalment_plans_df[instalment_plans_df['instalment_plan_id'] == 17489]
# Out:
#                         created        payment_method_fingerprint  \
# 13123  2021-05-18T21:28:20.481Z  add5885e26b1439db99536b38d88577d
#
#        downpayment_amount  billing_address_id  \
# 13123              166.67             24118.0
#
#                      device_fingerprint  total_downpayment  \
# 13123  5ae0e75c46fb92c954d8e41aae99225f             166.67
#
#              checkout_completed payment_method_brand    plan  \
# 13123  2021-05-18T21:28:12.264Z                 visa  funded
#
#       payment_method_expires  shipping_address_id  total_amount  \
# 13123             2026-02-28                  NaN         500.0
#
#                                merchant_id currency  customer_id gateway_name  \
# 13123  id_b9885ae6fad14ba0b3ea88bc5bab0f13      AED       9732.0   checkoutV2
#
#           id_number         checkout_verified cancelled  \
# 13123  7.841999e+14  2021-05-18T21:28:12.298Z       NaN
#
# ...

# %%
instalments_df[instalments_df['instalment_plan_id'] == 17489]
# Out:
#        order  refunded_amount  penalty_fee  amount  instalment_plan_id  \
# 85654      1              0.0         55.0  166.67               17489
# 85655      0              0.0         55.0  166.67               17489
#
#         scheduled completed  status   total
# 85654  2021-07-18       NaN  unpaid  221.67
# 85655  2021-06-18       NaN  unpaid  221.67

# %% [markdown]
# # Joins

# %%
instalments_df_sample = instalments_df[instalments_df['instalment_plan_id'] == 6237]
instalment_plans_df_sample = instalment_plans_df[instalment_plans_df['instalment_plan_id'] == 6237]
orders_df_sample = orders_df[orders_df['order_id'] == 11916]
customers_df_sample = customers_df[customers_df['customer_id'] == 3837.0]
transactions_df_sample = transactions_df[transactions_df['order_id'] == 11916]

# %%
pd.merge(instalment_plans_df_sample, instalments_df_sample, how='left', on=['instalment_plan_id']).head()
# Out:
#                     created        payment_method_fingerprint  \
# 0  2021-01-31T20:05:07.077Z  6f8ccc45ddd84045b6d18ef5f0544820
# 1  2021-01-31T20:05:07.077Z  6f8ccc45ddd84045b6d18ef5f0544820
#
#    downpayment_amount  billing_address_id                device_fingerprint  \
# 0              138.25                 NaN  0b3f6b6efcab68c03df3bbb4c92d9953
# 1              138.25                 NaN  0b3f6b6efcab68c03df3bbb4c92d9953
#
#    total_downpayment        checkout_completed payment_method_brand    plan  \
# 0             138.25  2021-01-31T20:03:54.307Z                 visa  funded
# 1             138.25  2021-01-31T20:03:54.307Z                 visa  funded
#
#   payment_method_expires  shipping_address_id  total_amount  \
# 0             2026-02-28               8298.0        414.75
# 1             2026-02-28               8298.0        414.75
#
#                            merchant_id currency  customer_id gateway_name  \
# ...

# %%
138.25*3
# Out:
# 414.75

# %%
import ness

# %%
dl = ness.dl(bucket="data.postpay.io", key="api", profile="default")

# %%
df_cart2 = dl.read("cart")
# Out:
# download: s3://data.postpay.io/api/cart.parquet_$folder$ to ../../../.ness/api/cart.parquet_$folder$
# download: s3://data.postpay.io/api/cart.parquet/part-00000-59c9b322-b528-4772-b4b9-990c000bf512-c000.gz.parquet to ../../../.ness/api/cart.parquet/part-00000-59c9b322-b528-4772-b4b9-990c000bf512-c000.gz.parquet

# %%
df_cart2.head()
# Out:
#   image_url unit_price  item_id  merchant_id url description  \
# 0                12.00    41163          271
# 1                16.00    99133          271
# 2                85.00    30750          280
# 3               100.00   140868          271
# 4                25.00    32749          280
#
#                                         name  reference  qty  order_id
# 0                   Pink Chiffon Body Lotion  229929847    1     47791
# 1  Fiji White Sands PocketBac Hand Sanitizer  249041946    1     75454
# 2                Wear Everywhere Push-Up Bra   31531960    1     42994
# 3               Tis the Season 3-Wick Candle  258041753    1     93548
# 4                  Sunkissed Fragrance Mists   32391979    1     44555

# %%
dl.sync()
# Out:
# download: s3://data.postpay.io/api/addresses.parquet_$folder$ to ../../../.ness/api/addresses.parquet_$folder$
# download: s3://data.postpay.io/api/cart.parquet_$folder$ to ../../../.ness/api/cart.parquet_$folder$
# download: s3://data.postpay.io/api/instalments.parquet_$folder$ to ../../../.ness/api/instalments.parquet_$folder$
# download: s3://data.postpay.io/api/instalment-plans.parquet_$folder$ to ../../../.ness/api/instalment-plans.parquet_$folder$
# download: s3://data.postpay.io/api/customers.parquet_$folder$ to ../../../.ness/api/customers.parquet_$folder$
# download: s3://data.postpay.io/api/orders.parquet_$folder$ to ../../../.ness/api/orders.parquet_$folder$
# download: s3://data.postpay.io/api/transactions.parquet_$folder$ to ../../../.ness/api/transactions.parquet_$folder$
# download: s3://data.postpay.io/api/refunds.parquet_$folder$ to ../../../.ness/api/refunds.parquet_$folder$
# ...
